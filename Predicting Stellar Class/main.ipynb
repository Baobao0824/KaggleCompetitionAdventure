# %%
import kagglehub

# %%
path = kagglehub.competition_download('playground-series-s6e6')

print(f"Path to competition files: {path}")
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 path = kagglehub.competition_download('playground-series-s6e6')
#       3 print(f"Path to competition files: {path}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/kagglehub/competition.py:23, in competition_download(handle, path, force_download)
#      21 h = parse_competition_handle(handle)
#      22 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23 path, _ = registry.competition_resolver(h, path, force_download=force_download)
#      24 return path
#
# File /opt/anaconda3/lib/python3.12/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
# ...
